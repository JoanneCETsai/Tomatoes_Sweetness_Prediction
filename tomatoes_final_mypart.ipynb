# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import urllib3
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
df = pd.read_csv('ML.csv')  
df
# Out:
#      number  pedicle  black_spot  green_or_yellow  tip  folds  weight  length  \
# 0         1        0         1.0                1    1      1    16.6     3.8
# 1         2        0         0.0                0    0      1     7.6     2.5
# 2         3        0         0.0                1    0      0     6.5     2.1
# 3         4        1         0.0                1    0      0    11.3     3.1
# 4         5        1         1.0                0    0      0     9.2     2.7
# ..      ...      ...         ...              ...  ...    ...     ...     ...
# 463     464        1         1.0                0    1      1     9.0     3.1
# 464     465        0         1.0                0    1      0     9.7     3.1
# 465     466        0         1.0                1    1      1     7.3     2.9
# 466     467        0         0.0                1    1      0     8.1     2.9
# 467     468        1         1.0                0    1      1     6.5     2.8
#
# ...

# %%
yflevel=pd.DataFrame(columns=['sweetness'],index=list(range(0,468)))
for i in range(0,468):
    if df.iloc[i,17]<= 4:
        yflevel.iloc[i,0] = 0
    elif 4.5<=df.iloc[i,17]<=5:
        yflevel.iloc[i,0] = 1
    elif 5.5<=df.iloc[i,17]<=6:
        yflevel.iloc[i,0] = 2
    elif 6.5<=df.iloc[i,17]<=7:
        yflevel.iloc[i,0] = 3
    elif df.iloc[i,17]>=7.5:
        yflevel.iloc[i,0] = 4
yflevel
# Out:
#     sweetness
# 0           2
# 1           2
# 2           0
# 3           0
# 4           0
# ..        ...
# 463         1
# 464         2
# 465         2
# 466         1
# 467         0
#
# [468 rows x 1 columns]

# %%
print(df[df.isnull().T.any()])
# Out:
#      number  pedicle  black_spot  green_or_yellow  tip  folds  weight  length  \
# 84       85        0         0.0                1    0      1     4.9     2.6
# 158     159        1         1.0                1    0      0    13.9     3.5
# 163     164        0         1.0                1    1      0     7.8     3.0
# 193     194        1         NaN                1    0      0     8.2     2.6
#
#      width  white  moisture   oil  elasticity  refraction    r   g   b  \
# 84     1.7    NaN       NaN   NaN         NaN      1.3410  109  33  17
# 158    2.5    NaN       NaN   NaN         NaN      1.3410  122  45  25
# 163    2.2    NaN       NaN   NaN         NaN      1.3410  114  41  22
# 193    2.1    7.0      21.0  57.0        41.0      1.3387  115  47  28
#
#      sweetness
# 84         5.5
# 158        5.5
# 163        5.5
# 193        4.0

# %%
df=df.drop([84,158,163,193])
df
# Out:
#      number  pedicle  black_spot  green_or_yellow  tip  folds  weight  length  \
# 0         1        0         1.0                1    1      1    16.6     3.8
# 1         2        0         0.0                0    0      1     7.6     2.5
# 2         3        0         0.0                1    0      0     6.5     2.1
# 3         4        1         0.0                1    0      0    11.3     3.1
# 4         5        1         1.0                0    0      0     9.2     2.7
# ..      ...      ...         ...              ...  ...    ...     ...     ...
# 463     464        1         1.0                0    1      1     9.0     3.1
# 464     465        0         1.0                0    1      0     9.7     3.1
# 465     466        0         1.0                1    1      1     7.3     2.9
# 466     467        0         0.0                1    1      0     8.1     2.9
# 467     468        1         1.0                0    1      1     6.5     2.8
#
# ...

# %%
x=df.drop(['sweetness'],axis=1)
x=x.drop(['number'],axis=1)
x
# Out:
#      pedicle  black_spot  green_or_yellow  tip  folds  weight  length  width  \
# 0          0         1.0                1    1      1    16.6     3.8    2.8
# 1          0         0.0                0    0      1     7.6     2.5    2.3
# 2          0         0.0                1    0      0     6.5     2.1    1.9
# 3          1         0.0                1    0      0    11.3     3.1    2.6
# 4          1         1.0                0    0      0     9.2     2.7    2.1
# ..       ...         ...              ...  ...    ...     ...     ...    ...
# 463        1         1.0                0    1      1     9.0     3.1    2.1
# 464        0         1.0                0    1      0     9.7     3.1    2.1
# 465        0         1.0                1    1      1     7.3     2.9    1.8
# 466        0         0.0                1    1      0     8.1     2.9    2.1
# 467        1         1.0                0    1      1     6.5     2.8    1.8
#
# ...

# %%
yflevel=yflevel.drop([84,158,163,193])
yflevel
# Out:
#     sweetness
# 0           2
# 1           2
# 2           0
# 3           0
# 4           0
# ..        ...
# 463         1
# 464         2
# 465         2
# 466         1
# 467         0
#
# [464 rows x 1 columns]

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
x
# Out:
#      pedicle  black_spot  green_or_yellow  tip  folds  weight  length  width  \
# 0          0         1.0                1    1      1    16.6     3.8    2.8
# 1          0         0.0                0    0      1     7.6     2.5    2.3
# 2          0         0.0                1    0      0     6.5     2.1    1.9
# 3          1         0.0                1    0      0    11.3     3.1    2.6
# 4          1         1.0                0    0      0     9.2     2.7    2.1
# ..       ...         ...              ...  ...    ...     ...     ...    ...
# 463        1         1.0                0    1      1     9.0     3.1    2.1
# 464        0         1.0                0    1      0     9.7     3.1    2.1
# 465        0         1.0                1    1      1     7.3     2.9    1.8
# 466        0         0.0                1    1      0     8.1     2.9    2.1
# 467        1         1.0                0    1      1     6.5     2.8    1.8
#
# ...

# %%
x.columns
# Out:
# Index(['pedicle', 'black_spot', 'green_or_yellow', 'tip', 'folds', 'weight',
#        'length', 'width', 'white', 'moisture', 'oil', 'elasticity',
#        'refraction', 'r', 'g', 'b'],
#       dtype='object')

# %%
model=LogisticRegression()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,yflevel,test_size=0.3)

# %%
from sklearn.preprocessing  import StandardScaler
sc=StandardScaler()

sc.fit(x_train)

x_train_nor=sc.transform(x_train)
x_test_nor=sc.transform(x_test)
model.fit(x_train_nor,y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-d3063ee56a66> in <module>
#       6 x_train_nor=sc.transform(x_train)
#       7 x_test_nor=sc.transform(x_test)
# ----> 8 model.fit(x_train_nor,y_train)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1343                                    order="C",
#    1344                                    accept_large_sparse=solver != 'liblinear')
# -> 1345         check_classification_targets(y)
#    1346         self.classes_ = np.unique(y)
#    1347
#
# ...

# %%
DataFrame[df.isnull().T.any()]
